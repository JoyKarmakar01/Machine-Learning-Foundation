# %% [markdown]
# ### Decision Tree Algorithms: A Comprehensive Guide
#
# #### Introduction
#
# A Decision Tree is a popular supervised learning algorithm used for both classification and regression tasks. It is a tree-like model of decisions and their possible consequences, including chance event outcomes, resource costs, and utility. Decision Trees aim to create a model that predicts the value of a target variable by learning simple decision rules inferred from data features.
#
# #### How Decision Trees Work
#
# 1. **Splitting**: The process of dividing a node into two or more sub-nodes.
# 2. **Decision Node**: When a sub-node splits into further sub-nodes.
# 3. **Leaf/Terminal Node**: Nodes that do not split.
# 4. **Pruning**: The process of removing sub-nodes of a decision node.
# 5. **Branch/Sub-Tree**: A subsection of the entire tree.
# 6. **Root Node**: The topmost node in a decision tree.
#
# The goal is to create the most optimal splits based on features to best segment the data into pure subsets.
#
# #### Key Concepts
#
# 1. **Gini Index**: Measures the impurity of a node. Lower values indicate less impurity.
# 2. **Entropy**: Measures the randomness in the information being processed. Higher entropy indicates more disorder.
# 3. **Information Gain**: Measures the reduction in entropy or surprise by transforming a dataset and is used to decide the splits in the tree.
# 4. **Chi-Square**: Used for categorical variables in classification trees. It measures the statistical significance of splits.
#
# #### Advantages
#
# - **Simple to Understand and Interpret**: Easy to visualize and explain to non-technical stakeholders.
# - **No Need for Feature Scaling**: Decision Trees do not require normalization or standardization of data.
# - **Handles Both Numerical and Categorical Data**: Versatile in handling different types of data.
# - **Non-Parametric**: No assumptions about the space distribution and the classifier structure.
#
# #### Disadvantages
#
# - **Overfitting**: Prone to overfitting, especially with complex trees.
# - **Bias**: Sensitive to biased datasets; a small change can result in a completely different tree.
# - **Not Good for Smooth Boundaries**: Decision Trees can create biased boundaries when the data has smooth changes.
#
# #### Steps to Build a Decision Tree
#
# 1. **Data Preparation**: Clean the data and handle missing values.
# 2. **Train-Test Split**: Split the dataset into training and test sets.
# 3. **Model Training**: Train the decision tree using criteria like Gini Index, Entropy, or Chi-Square.
# 4. **Model Evaluation**: Assess the performance using appropriate metrics.
# 5. **Pruning**: Reduce the size of the tree to prevent overfitting.
# 6. **Visualization**: Visualize the decision tree for interpretability.

# %% [markdown]
# ## Python Implementation
# Here’s how you can implement a Decision Tree classifier using Python and the `scikit-learn` library.
#
# python

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree classifier
dt = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)

# Train the model
dt.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=iris.target_names))

# Print the confusion matrix
print("\nConfusion Matrix:")
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)

# Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(dt, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True)
plt.show()
# Out:
# C:\Users\karma\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Accuracy: 100.00%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %% [markdown]
# ```
#
# ### Explanation of the Code
#
# - **Data Loading**: Using the `load_iris()` function to load the Iris dataset.
# - **Data Splitting**: Splitting the dataset into training and testing sets using `train_test_split()`.
# - **Model Initialization**: Initializing a `DecisionTreeClassifier` with the criterion set to 'gini' and a maximum depth of 3.
# - **Model Training**: Training the model on the training data.
# - **Prediction**: Making predictions on the test set.
# - **Evaluation**: Using accuracy, classification report, and confusion matrix to evaluate the model’s performance.
# - **Visualization**: Visualizing the decision tree using `plot_tree()`.
#
# ### Hyperparameter Tuning
#
# - `criterion`: Function to measure the quality of a split ('gini' for Gini impurity, 'entropy' for information gain).
# - `max_depth`: Maximum depth of the tree.
# - `min_samples_split`: Minimum number of samples required to split an internal node.
# - `min_samples_leaf`: Minimum number of samples required to be at a leaf node.
# - `max_features`: Number of features to consider when looking for the best split.
#
# ### Conclusion
#
# Decision Trees are a fundamental and powerful machine learning algorithm, especially when combined with ensemble methods like Random Forests. Their simplicity and interpretability make them a valuable tool in the data scientist’s toolkit. However, careful consideration must be given to their limitations and the risk of overfitting. Proper tuning and pruning are essential to building robust and reliable models.
